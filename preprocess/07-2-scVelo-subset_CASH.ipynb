# %% [markdown]
# ## 1. load packages

# %%
import os
import numpy as np
import pandas as pd
import scvelo as scv

# %% [markdown]
# ## 2. params

# %%
os.chdir("D:/Projects/CASH-Human/")
dir_for_loom = "./data/loom/merge.loom"

# %% [markdown]
# ## 3. load loom data

# %%
ldata = scv.read(dir_for_loom, cache=False)
ldata.var_names_make_unique()
print(ldata)
print(ldata.obs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ldata = scv.read(dir_for_loom, cache=False)
#       2 ldata.var_names_make_unique()
#       3 print(ldata)
#
# File d:\software\anaconda3\Lib\site-packages\legacy_api_wrap\__init__.py:80, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      77 @wraps(fn)
#      78 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      79     if len(args_all) <= n_positional:
# ---> 80         return fn(*args_all, **kw)
#      82     args_pos: P.args
#      83     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File d:\software\anaconda3\Lib\site-packages\scanpy\readwrite.py:129, in read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, **kwargs)
#     127 filename = Path(filename)  # allow passing strings
#     128 if is_valid_filename(filename):
# --> 129     return _read(
#     130         filename,
#     131         backed=backed,
#     132         sheet=sheet,
#     133         ext=ext,
#     134         delimiter=delimiter,
#     135         first_column_names=first_column_names,
#     136         backup_url=backup_url,
#     137         cache=cache,
#     138         cache_compression=cache_compression,
#     139         **kwargs,
#     140     )
#     141 # generate filename and read to dict
#     142 filekey = str(filename)
#
# File d:\software\anaconda3\Lib\site-packages\scanpy\readwrite.py:810, in _read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, suppress_cache_warning, **kwargs)
#     808     adata = _read_softgz(filename)
#     809 elif ext == "loom":
# --> 810     adata = read_loom(filename=filename, **kwargs)
#     811 else:
#     812     raise ValueError(f"Unknown extension {ext}.")
#
# File d:\software\anaconda3\Lib\site-packages\anndata\compat\__init__.py:359, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     357 extra_args = len(args) - len(all_args)
#     358 if extra_args <= 0:
# --> 359     return f(*args, **kwargs)
#     361 # extra_args > 0
#     362 args_msg = [
#     363     f"{name}={arg}"
#     364     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#     365 ]
#
# File d:\software\anaconda3\Lib\site-packages\anndata\_io\read.py:254, in read_loom(filename, sparse, cleanup, X_name, obs_names, obsm_names, var_names, varm_names, dtype, obsm_mapping, varm_mapping, **kwargs)
#     252 if X_name not in lc.layers.keys():
#     253     X_name = ""
# --> 254 X = lc.layers[X_name].sparse().T.tocsr() if sparse else lc.layers[X_name][()].T
#     255 X = X.astype(dtype, copy=False)
#     257 layers = OrderedDict()
#
# File d:\software\anaconda3\Lib\site-packages\loompy\loom_layer.py:118, in LoomLayer.sparse(self, rows, cols)
#     116 col: List[np.ndarray] = []
#     117 i = 0
# --> 118 for (ix, selection, view) in self.ds.scan(items=cols, axis=1, layers=[self.name], what=["layers"]):
#     119 	if rows is not None:
#     120 		vals = view.layers[self.name][rows, :]
#
# File d:\software\anaconda3\Lib\site-packages\loompy\loompy.py:618, in LoomConnection.scan(self, items, axis, layers, key, batch_size, what)
#     616 # Load the whole chunk from the file, then extract genes and cells using fancy indexing
#     617 for layer in layers:
# --> 618 	temp = self.layers[layer][:, ix:ix + cols_per_chunk]
#     619 	temp = temp[ordering, :]
#     620 	if selection is not None:
#
# File d:\software\anaconda3\Lib\site-packages\loompy\loom_layer.py:89, in LoomLayer.__getitem__(self, slice)
#      87 if self.name == "":
#      88 	return self.ds._file['/matrix'].__getitem__(slice)
# ---> 89 return self.ds._file['/layers/' + self.name].__getitem__(slice)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File d:\software\anaconda3\Lib\site-packages\h5py\_hl\dataset.py:758, in Dataset.__getitem__(self, args, new_dtype)
#     756 if self._fast_read_ok and (new_dtype is None):
#     757     try:
# --> 758         return self._fast_reader.read(args)
#     759     except TypeError:
#     760         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. add meta

# %%
ldata.obs["patient"] = ldata.obs.index.str.split(':').str[0]
ldata.obs["barcode"] = ldata.obs.index.str.split(':').str[1]
ldata.obs['group'] = ldata.obs.patient.str[0]
ldata.obs["barcode"] = ldata.obs.barcode.str.rstrip('x')
ldata.obs['patient_id'] = ldata.obs.patient.str[1]
ldata.obs["barcode"] = ldata.obs.barcode + '-' + ldata.obs.patient_id
print(ldata.obs)
print(len(ldata.obs['barcode']))
print(len(ldata.obs['barcode'].unique()))

# %% [markdown]
# ## 5.Subset CASH loom data

# %%
# subset
ldata_N = ldata[ldata.obs.group == "N"]
ldata_sub = ldata_N[ldata_N.obs.patient_id != '5']
print("ldata_N:", ldata_N)
print("ldata_sub:", ldata_sub)
print(ldata_sub.obs.head())
print("ldata_sub_patient:", pd.unique(ldata_sub.obs["patient"]))
print("ldata_sub_barcode:", len(ldata_sub.obs['barcode']))

# %% [markdown]
# ### 5-1. meta

# %%
ldata_sub.obs.group = ldata_sub.obs.group.replace("N", "CASH")
ldata_sub.obs.patient = ldata_sub.obs.patient.replace({
    'N3': 'Patient1',
    'N4': 'Patient2',
    'N6': 'Patient4',
    'N7': 'Patient5'
})
ldata_sub.obs.patient_id = ldata_sub.obs.patient.str[-1]
ldata_sub.obs.barcode = ldata_sub.obs.apply(
    lambda row: row.barcode.replace(r'-' + row.barcode.split('-')[-1], '-' + row.patient_id),
    axis=1
)
print("ldata_sub:", ldata_sub)
print(ldata_sub.obs.head())
## save
ldata_sub.write('./data/loom/ldata_CASH.h5ad', compression = 'gzip')

# %% [markdown]
# ## 6. subset ldata per cell

# %% [markdown]
# ### 6-1 params

# %%
dir_for_ldata_CASH = "./data/loom/ldata_CASH.h5ad"
dir_for_obj_meta = "./data/obj_meta/"

# %% [markdown]
# ### 6-3 load data

# %%
ldata = scv.read(dir_for_ldata_CASH, cache=False)
ldata.var_names_make_unique()
print("ldata:", ldata)
print(ldata.obs.head())
print("ldata:", len(ldata.obs['barcode'].unique()))
# Out:
# ldata: AnnData object with n_obs × n_vars = 26440 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id
# CellID
# N3:AAAGTAGCACCAACCGx  Patient1  AAAGTAGCACCAACCG-1  CASH          1
# N3:AAATGCCCATTAACCGx  Patient1  AAATGCCCATTAACCG-1  CASH          1
# N3:AAAGTAGCATGTTCCCx  Patient1  AAAGTAGCATGTTCCC-1  CASH          1
# N3:AAAGTAGTCAACTCTTx  Patient1  AAAGTAGTCAACTCTT-1  CASH          1
# N3:AACCATGCAGTCACTAx  Patient1  AACCATGCAGTCACTA-1  CASH          1
# ldata: 26440

# %% [markdown]
# ### 6-4 subset

# %%
dir_for_ldata_sub = "./data/loom/ldata_sub"
if os.path.exists(dir_for_ldata_sub):
    print("directory has been created")
else:
    os.makedirs(dir_for_ldata_sub)
    print(f"Created directory: {dir_for_ldata_sub}")

for i_file in os.listdir(dir_for_obj_meta):
    # if i_file != "T_obj_meta.csv":
    #     continue
    # i_file = "T_obj_meta.csv"
    print(i_file)
    cell = str.split(i_file, "_")[0]
    print(cell)

    ## load meta
    meta = pd.read_csv(os.path.join(dir_for_obj_meta, i_file))
    print(f"meta_{cell}:\n", len(meta))
    print(f"meta_{cell}:\n", meta.head(1))

    ## subset
    ldata_sub = ldata[np.isin(ldata.obs["barcode"], meta["barcode"])]
    print(f"ldata_sub_{cell}: {ldata_sub}")
    print(f"ldata_sub_{cell}:\n {ldata_sub.obs.head(1)}")

    ## add meta
    ### sub_celltype
    meta_matched = ldata_sub.obs[["barcode"]].merge(meta, on="barcode", how="left")
    print(f"meta_{cell}:\n", meta_matched.head(1))
    ldata_sub.obs["sub_celltype"] = meta_matched["sub_celltype"].values
    print(f"ldata_sub_{cell}:\n {ldata_sub.obs.head(1)}")

    ### UMAP coord
    ldata_sub.obsm["X_umap"] = meta_matched[["UMAP1", "UMAP2"]].values

    # print(f"Updated ldata_sub.obs:\n {ldata_sub.obs.head(1)}")
    # print(f"Updated ldata_sub.obsm['X_umap']:\n {ldata_sub.obsm['X_umap'][:1]}")


    # meta_matched = ldata_sub.obs[["barcode"]].merge(meta, on = "barcode", how = "left")
    # print(meta_matched)
    # ldata_sub.obs["cluster"] = meta_matched["sub_celltype"].values
    # ldata_sub.obs["UMAP1"] = meta_matched["UMAP1"].values
    # ldata_sub.obs["UMAP2"] = meta_matched["UMAP2"].values
    # umap = ldata_sub.obs[["barcode", "UMAP1", "UMAP2"]]
    # umap.set_index("barcode", inplace=True)
    # ldata_sub.obsm["umap"] = umap.values 
    print(ldata_sub)
    print(ldata_sub.obs.head())
    print(ldata_sub.obsm)
    ldata_sub.write(os.path.join(dir_for_ldata_sub, f"{cell}_ldata.h5ad"), compression= "gzip")
# Out:
# directory has been created
# B_obj_meta.csv
# B
# meta_B:
#  673
# meta_B:
#                barcode     orig.ident group   patient  sub_celltype     UMAP1  \
# 0  AAAGTAGCAGCTCGCA-1  CASH_Patient1  CASH  Patient1  c36_Bn_TCL1A -1.474113
#
#       UMAP2
# 0 -1.295199
# ldata_sub_B: View of AnnData object with n_obs × n_vars = 673 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
# ldata_sub_B:
#                         patient             barcode group patient_id
# CellID
# N3:AAAGTAGCAGCTCGCAx  Patient1  AAAGTAGCAGCTCGCA-1  CASH          1
# meta_B:
#                barcode     orig.ident group   patient  sub_celltype     UMAP1  \
# 0  AAAGTAGCAGCTCGCA-1  CASH_Patient1  CASH  Patient1  c36_Bn_TCL1A -1.474113
#
#       UMAP2
# 0 -1.295199
# ldata_sub_B:
#                         patient             barcode group patient_id  \
# CellID
# N3:AAAGTAGCAGCTCGCAx  Patient1  AAAGTAGCAGCTCGCA-1  CASH          1
#
#                       sub_celltype
# CellID
# N3:AAAGTAGCAGCTCGCAx  c36_Bn_TCL1A
# AnnData object with n_obs × n_vars = 673 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id', 'sub_celltype'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     obsm: 'X_umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id  \
# CellID
# N3:AAAGTAGCAGCTCGCAx  Patient1  AAAGTAGCAGCTCGCA-1  CASH          1
# N3:AACCATGAGTGCGATGx  Patient1  AACCATGAGTGCGATG-1  CASH          1
# N3:AAGACCTGTAGCGATGx  Patient1  AAGACCTGTAGCGATG-1  CASH          1
# N3:AATCCAGAGTAATCCCx  Patient1  AATCCAGAGTAATCCC-1  CASH          1
# N3:AATCGGTTCTTAACCTx  Patient1  AATCGGTTCTTAACCT-1  CASH          1
#
#                        sub_celltype
# CellID
# N3:AAAGTAGCAGCTCGCAx   c36_Bn_TCL1A
# N3:AACCATGAGTGCGATGx         c35_PC
# N3:AAGACCTGTAGCGATGx   c36_Bn_TCL1A
# N3:AATCCAGAGTAATCCCx  c40_Bgc_MKI67
# N3:AATCGGTTCTTAACCTx         c35_PC
# AxisArrays with keys: X_umap
# Myeloid_obj_meta.csv
# Myeloid
# meta_Myeloid:
#  3622
# meta_Myeloid:
#                barcode     orig.ident group   patient        sub_celltype  \
# 0  AAACCTGTCACAAACC-1  CASH_Patient1  CASH  Patient1  c02_ Monocyte_CD14
#
#      UMAP1     UMAP2
# 0 -2.96368 -4.877204
# ldata_sub_Myeloid: View of AnnData object with n_obs × n_vars = 3622 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
# ldata_sub_Myeloid:
#                         patient             barcode group patient_id
# CellID
# N3:AACACGTTCATTGCCCx  Patient1  AACACGTTCATTGCCC-1  CASH          1
# meta_Myeloid:
#                barcode     orig.ident group   patient        sub_celltype  \
# 0  AACACGTTCATTGCCC-1  CASH_Patient1  CASH  Patient1  c02_ Monocyte_CD14
#
#       UMAP1     UMAP2
# 0 -2.229901 -4.655958
# ldata_sub_Myeloid:
#                         patient             barcode group patient_id  \
# CellID
# N3:AACACGTTCATTGCCCx  Patient1  AACACGTTCATTGCCC-1  CASH          1
#
#                             sub_celltype
# CellID
# N3:AACACGTTCATTGCCCx  c02_ Monocyte_CD14
# AnnData object with n_obs × n_vars = 3622 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id', 'sub_celltype'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     obsm: 'X_umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id  \
# CellID
# N3:AACACGTTCATTGCCCx  Patient1  AACACGTTCATTGCCC-1  CASH          1
# N3:AAACCTGTCACAAACCx  Patient1  AAACCTGTCACAAACC-1  CASH          1
# N3:AACCATGGTGTCAATCx  Patient1  AACCATGGTGTCAATC-1  CASH          1
# N3:AAAGTAGGTCTGATCAx  Patient1  AAAGTAGGTCTGATCA-1  CASH          1
# N3:AAACCTGTCATATCGGx  Patient1  AAACCTGTCATATCGG-1  CASH          1
#
#                                 sub_celltype
# CellID
# N3:AACACGTTCATTGCCCx      c02_ Monocyte_CD14
# N3:AAACCTGTCACAAACCx      c02_ Monocyte_CD14
# N3:AACCATGGTGTCAATCx      c02_ Monocyte_CD14
# N3:AAAGTAGGTCTGATCAx        c05_ Macrophage_
# N3:AAACCTGTCATATCGGx  c01_ Monocyte_CD14CD16
# AxisArrays with keys: X_umap
# NK_obj_meta.csv
# NK
# meta_NK:
#  2830
# meta_NK:
#                barcode     orig.ident group   patient sub_celltype     UMAP1  \
# 0  AAACCTGCACCCATTC-1  CASH_Patient1  CASH  Patient1  c32_NK_CREM -6.797893
#
#       UMAP2
# 0  0.759612
# ldata_sub_NK: View of AnnData object with n_obs × n_vars = 2830 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
# ldata_sub_NK:
#                         patient             barcode group patient_id
# CellID
# N3:AAAGTAGCACCAACCGx  Patient1  AAAGTAGCACCAACCG-1  CASH          1
# meta_NK:
#                barcode     orig.ident group   patient   sub_celltype    UMAP1  \
# 0  AAAGTAGCACCAACCG-1  CASH_Patient1  CASH  Patient1  c29_NK_NFKBIA  5.34998
#
#       UMAP2
# 0  1.551205
# ldata_sub_NK:
#                         patient             barcode group patient_id  \
# CellID
# N3:AAAGTAGCACCAACCGx  Patient1  AAAGTAGCACCAACCG-1  CASH          1
#
#                        sub_celltype
# CellID
# N3:AAAGTAGCACCAACCGx  c29_NK_NFKBIA
# AnnData object with n_obs × n_vars = 2830 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id', 'sub_celltype'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     obsm: 'X_umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id  \
# CellID
# N3:AAAGTAGCACCAACCGx  Patient1  AAAGTAGCACCAACCG-1  CASH          1
# N3:AAATGCCCAACTGGCCx  Patient1  AAATGCCCAACTGGCC-1  CASH          1
# N3:AAATGCCAGATGCCAGx  Patient1  AAATGCCAGATGCCAG-1  CASH          1
# N3:AACCGCGAGCGTGTCCx  Patient1  AACCGCGAGCGTGTCC-1  CASH          1
# N3:AACACGTCACAGGTTTx  Patient1  AACACGTCACAGGTTT-1  CASH          1
#
#                        sub_celltype
# CellID
# N3:AAAGTAGCACCAACCGx  c29_NK_NFKBIA
# N3:AAATGCCCAACTGGCCx   c28_NK_CD160
# N3:AAATGCCAGATGCCAGx  c29_NK_NFKBIA
# N3:AACCGCGAGCGTGTCCx   c28_NK_CD160
# N3:AACACGTCACAGGTTTx   c28_NK_CD160
# AxisArrays with keys: X_umap
# T_obj_meta.csv
# T
# meta_T:
#  8539
# meta_T:
#                barcode     orig.ident group   patient sub_celltype     UMAP1  \
# 0  AAACCTGCAAATCCGT-1  CASH_Patient1  CASH  Patient1     c17_CD8_ -2.918159
#
#       UMAP2
# 0 -1.970783
# ldata_sub_T: View of AnnData object with n_obs × n_vars = 8539 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
# ldata_sub_T:
#                         patient             barcode group patient_id
# CellID
# N3:AACCATGCAGTCACTAx  Patient1  AACCATGCAGTCACTA-1  CASH          1
# meta_T:
#                barcode     orig.ident group   patient sub_celltype     UMAP1  \
# 0  AACCATGCAGTCACTA-1  CASH_Patient1  CASH  Patient1     c17_CD8_ -4.316454
#
#       UMAP2
# 0 -2.035403
# ldata_sub_T:
#                         patient             barcode group patient_id  \
# CellID
# N3:AACCATGCAGTCACTAx  Patient1  AACCATGCAGTCACTA-1  CASH          1
#
#                      sub_celltype
# CellID
# N3:AACCATGCAGTCACTAx     c17_CD8_
# AnnData object with n_obs × n_vars = 8539 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id', 'sub_celltype'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     obsm: 'X_umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id  \
# CellID
# N3:AACCATGCAGTCACTAx  Patient1  AACCATGCAGTCACTA-1  CASH          1
# N3:AACACGTTCCTCTAGCx  Patient1  AACACGTTCCTCTAGC-1  CASH          1
# N3:AAAGATGAGCTAAACAx  Patient1  AAAGATGAGCTAAACA-1  CASH          1
# N3:AAACGGGGTATCACCAx  Patient1  AAACGGGGTATCACCA-1  CASH          1
# N3:AAAGATGGTTACGTCAx  Patient1  AAAGATGGTTACGTCA-1  CASH          1
#
#                      sub_celltype
# CellID
# N3:AACCATGCAGTCACTAx     c17_CD8_
# N3:AACACGTTCCTCTAGCx     c17_CD8_
# N3:AAAGATGAGCTAAACAx     c20_CD8_
# N3:AAACGGGGTATCACCAx     c18_CD8_
# N3:AAAGATGGTTACGTCAx     c21_CD8_
# AxisArrays with keys: X_umap
