# %% [markdown]
# ## 1.load packages

# %%
import os
import numpy as np
import pandas as pd
import scvelo as scv

# %% [markdown]
# ## 2.params

# %%
os.chdir("D:/Projects/CASH-Human/")
dir_for_ldata_CASH = "./data/loom/ldata_CASH.h5ad"
dir_for_obj_meta = "./data/obj_meta/"

# %% [markdown]
# ## 3. Load ldata_CASH

# %%
ldata = scv.read(dir_for_ldata_CASH, cache=False)
ldata.var_names_make_unique()
print(ldata)
print(ldata.obs)
print(len(ldata.obs['barcode']))
print(len(ldata.obs['barcode'].unique()))
# Out:
# AnnData object with n_obs × n_vars = 26440 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id
# CellID
# N3:AAAGTAGCACCAACCGx  Patient1  AAAGTAGCACCAACCG-1  CASH          1
# N3:AAATGCCCATTAACCGx  Patient1  AAATGCCCATTAACCG-1  CASH          1
# N3:AAAGTAGCATGTTCCCx  Patient1  AAAGTAGCATGTTCCC-1  CASH          1
# N3:AAAGTAGTCAACTCTTx  Patient1  AAAGTAGTCAACTCTT-1  CASH          1
# N3:AACCATGCAGTCACTAx  Patient1  AACCATGCAGTCACTA-1  CASH          1
# ...                        ...                 ...   ...        ...
# N7:TTTGTCATCTACTCATx  Patient5  TTTGTCATCTACTCAT-5  CASH          5
# N7:TTTGTCACAAGCCGCTx  Patient5  TTTGTCACAAGCCGCT-5  CASH          5
# N7:TTTGTCATCGAACGGAx  Patient5  TTTGTCATCGAACGGA-5  CASH          5
# N7:TTTGGTTGTGCATCTAx  Patient5  TTTGGTTGTGCATCTA-5  CASH          5
# N7:TTTGGTTCATGGTCTAx  Patient5  TTTGGTTCATGGTCTA-5  CASH          5
#
# [26440 rows x 4 columns]
# 26440
# 26440

# %% [markdown]
# ## 4. subset ldata per cell

# %%
dir_for_ldata_sub = "./data/loom/ldata_sub"
if os.path.exists(dir_for_ldata_sub):
    print("directory has been created")
else:
    os.makedirs(dir_for_ldata_sub)
    print(f"Created directory: {dir_for_ldata_sub}")

for i_file in os.listdir(dir_for_obj_meta):
    print(i_file)
    cell = str.split(i_file, "_")[0]
    print(cell)

    ## load meta
    meta = pd.read_csv(os.path.join(dir_for_obj_meta, i_file))
    print(meta.head(1))

    ## subset
    ldata_sub = ldata[np.isin(ldata.obs.barcode, meta.barcode)]
    print(ldata_sub)
    print(ldata_sub.obs)

    ## add meta
    meta_matched = ldata_sub.obs[["barcode"]].merge(meta, on = "barcode", how = "left")
    print(meta_matched)
    ldata_sub.obs["cluster"] = meta_matched["sub_celltype"].values
    ldata_sub.obs["UMAP1"] = meta_matched["UMAP1"].values
    ldata_sub.obs["UMAP2"] = meta_matched["UMAP2"].values
    umap = ldata_sub.obs[["barcode", "UMAP1", "UMAP2"]]
    umap.set_index("barcode", inplace=True)
    ldata_sub.obsm["umap"] = umap.values 
    print(ldata_sub)
    print(ldata_sub.obs.head())
    print(ldata_sub.obsm)
    ldata_sub.write(os.path.join(dir_for_ldata_sub, f"{cell}_ldata.h5ad"), compression= "gzip")
# Out:
# directory has been created
# B_obj_meta.csv
# B
#               barcode     orig.ident group   patient  sub_celltype     UMAP1  \
# 0  AAAGTAGCAGCTCGCA-1  CASH_Patient1  CASH  Patient1  c36_Bn_TCL1A -1.474113
#
#       UMAP2
# 0 -1.295199
# View of AnnData object with n_obs × n_vars = 673 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id
# CellID
# N3:AAAGTAGCAGCTCGCAx  Patient1  AAAGTAGCAGCTCGCA-1  CASH          1
# N3:AACCATGAGTGCGATGx  Patient1  AACCATGAGTGCGATG-1  CASH          1
# N3:AAGACCTGTAGCGATGx  Patient1  AAGACCTGTAGCGATG-1  CASH          1
# N3:AATCCAGAGTAATCCCx  Patient1  AATCCAGAGTAATCCC-1  CASH          1
# N3:AATCGGTTCTTAACCTx  Patient1  AATCGGTTCTTAACCT-1  CASH          1
# ...                        ...                 ...   ...        ...
# N7:TTTGCGCGTAGGGACTx  Patient5  TTTGCGCGTAGGGACT-5  CASH          5
# N7:TTTATGCCACAGACAGx  Patient5  TTTATGCCACAGACAG-5  CASH          5
# N7:TTTATGCTCTTGCAAGx  Patient5  TTTATGCTCTTGCAAG-5  CASH          5
# N7:TTTACTGTCCTGTACCx  Patient5  TTTACTGTCCTGTACC-5  CASH          5
# N7:TTTATGCGTCCCGACAx  Patient5  TTTATGCGTCCCGACA-5  CASH          5
#
# [673 rows x 4 columns]
#                 barcode     orig.ident group   patient   sub_celltype  \
# 0    AAAGTAGCAGCTCGCA-1  CASH_Patient1  CASH  Patient1   c36_Bn_TCL1A
# 1    AACCATGAGTGCGATG-1  CASH_Patient1  CASH  Patient1         c35_PC
# 2    AAGACCTGTAGCGATG-1  CASH_Patient1  CASH  Patient1   c36_Bn_TCL1A
# 3    AATCCAGAGTAATCCC-1  CASH_Patient1  CASH  Patient1  c40_Bgc_MKI67
# 4    AATCGGTTCTTAACCT-1  CASH_Patient1  CASH  Patient1         c35_PC
# ..                  ...            ...   ...       ...            ...
# 668  TTTGCGCGTAGGGACT-5  CASH_Patient5  CASH  Patient5   c36_Bn_TCL1A
# 669  TTTATGCCACAGACAG-5  CASH_Patient5  CASH  Patient5   c36_Bn_TCL1A
# 670  TTTATGCTCTTGCAAG-5  CASH_Patient5  CASH  Patient5         c35_PC
# 671  TTTACTGTCCTGTACC-5  CASH_Patient5  CASH  Patient5   c36_Bn_TCL1A
# 672  TTTATGCGTCCCGACA-5  CASH_Patient5  CASH  Patient5         c35_PC
#
#         UMAP1     UMAP2
# 0   -1.474113 -1.295199
# 1    0.853529  2.186431
# 2    4.614146  0.382808
# 3    2.171818  5.204569
# 4    5.231277  1.533176
# ..        ...       ...
# 668 -1.450575 -1.265543
# 669 -1.301458 -0.112056
# 670  3.474099 -2.206979
# 671 -0.885049 -0.613219
# 672  3.541487 -0.189386
#
# [673 rows x 7 columns]
# AnnData object with n_obs × n_vars = 673 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id', 'cluster', 'UMAP1', 'UMAP2'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     obsm: 'umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id  \
# CellID
# N3:AAAGTAGCAGCTCGCAx  Patient1  AAAGTAGCAGCTCGCA-1  CASH          1
# N3:AACCATGAGTGCGATGx  Patient1  AACCATGAGTGCGATG-1  CASH          1
# N3:AAGACCTGTAGCGATGx  Patient1  AAGACCTGTAGCGATG-1  CASH          1
# N3:AATCCAGAGTAATCCCx  Patient1  AATCCAGAGTAATCCC-1  CASH          1
# N3:AATCGGTTCTTAACCTx  Patient1  AATCGGTTCTTAACCT-1  CASH          1
#
#                             cluster     UMAP1     UMAP2
# CellID
# N3:AAAGTAGCAGCTCGCAx   c36_Bn_TCL1A -1.474113 -1.295199
# N3:AACCATGAGTGCGATGx         c35_PC  0.853529  2.186431
# N3:AAGACCTGTAGCGATGx   c36_Bn_TCL1A  4.614146  0.382808
# N3:AATCCAGAGTAATCCCx  c40_Bgc_MKI67  2.171818  5.204569
# N3:AATCGGTTCTTAACCTx         c35_PC  5.231277  1.533176
# AxisArrays with keys: umap
# Myeloid_obj_meta.csv
# Myeloid
#               barcode     orig.ident group   patient        sub_celltype  \
# 0  AAACCTGTCACAAACC-1  CASH_Patient1  CASH  Patient1  c02_ Monocyte_CD14
#
#      UMAP1     UMAP2
# 0 -2.96368 -4.877204
# View of AnnData object with n_obs × n_vars = 3622 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id
# CellID
# N3:AACACGTTCATTGCCCx  Patient1  AACACGTTCATTGCCC-1  CASH          1
# N3:AAACCTGTCACAAACCx  Patient1  AAACCTGTCACAAACC-1  CASH          1
# N3:AACCATGGTGTCAATCx  Patient1  AACCATGGTGTCAATC-1  CASH          1
# N3:AAAGTAGGTCTGATCAx  Patient1  AAAGTAGGTCTGATCA-1  CASH          1
# N3:AAACCTGTCATATCGGx  Patient1  AAACCTGTCATATCGG-1  CASH          1
# ...                        ...                 ...   ...        ...
# N7:TTTGTCACAGTGGAGTx  Patient5  TTTGTCACAGTGGAGT-5  CASH          5
# N7:TTTGTCACATGTAGTCx  Patient5  TTTGTCACATGTAGTC-5  CASH          5
# N7:TTTGTCATCTACTCATx  Patient5  TTTGTCATCTACTCAT-5  CASH          5
# N7:TTTGTCACAAGCCGCTx  Patient5  TTTGTCACAAGCCGCT-5  CASH          5
# N7:TTTGGTTCATGGTCTAx  Patient5  TTTGGTTCATGGTCTA-5  CASH          5
#
# [3622 rows x 4 columns]
#                  barcode     orig.ident group   patient  \
# 0     AACACGTTCATTGCCC-1  CASH_Patient1  CASH  Patient1
# 1     AAACCTGTCACAAACC-1  CASH_Patient1  CASH  Patient1
# 2     AACCATGGTGTCAATC-1  CASH_Patient1  CASH  Patient1
# 3     AAAGTAGGTCTGATCA-1  CASH_Patient1  CASH  Patient1
# 4     AAACCTGTCATATCGG-1  CASH_Patient1  CASH  Patient1
# ...                  ...            ...   ...       ...
# 3617  TTTGTCACAGTGGAGT-5  CASH_Patient5  CASH  Patient5
# 3618  TTTGTCACATGTAGTC-5  CASH_Patient5  CASH  Patient5
# 3619  TTTGTCATCTACTCAT-5  CASH_Patient5  CASH  Patient5
# 3620  TTTGTCACAAGCCGCT-5  CASH_Patient5  CASH  Patient5
# 3621  TTTGGTTCATGGTCTA-5  CASH_Patient5  CASH  Patient5
#
#                 sub_celltype     UMAP1     UMAP2
# 0         c02_ Monocyte_CD14 -2.229901 -4.655958
# 1         c02_ Monocyte_CD14 -2.963680 -4.877204
# 2         c02_ Monocyte_CD14 -3.613648 -6.833498
# 3           c05_ Macrophage_ -0.632350  1.862864
# 4     c01_ Monocyte_CD14CD16 -0.766415 -2.732157
# ...                      ...       ...       ...
# 3617        c06_ Macrophage_ -0.217952  3.736627
# 3618  c01_ Monocyte_CD14CD16 -0.444185 -3.397153
# 3619        c06_ Macrophage_  0.501036  2.425329
# 3620        c06_ Macrophage_ -0.021637  2.603315
# 3621                c11_cDC2 -5.675398  3.849182
#
# [3622 rows x 7 columns]
# AnnData object with n_obs × n_vars = 3622 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id', 'cluster', 'UMAP1', 'UMAP2'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     obsm: 'umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id  \
# CellID
# N3:AACACGTTCATTGCCCx  Patient1  AACACGTTCATTGCCC-1  CASH          1
# N3:AAACCTGTCACAAACCx  Patient1  AAACCTGTCACAAACC-1  CASH          1
# N3:AACCATGGTGTCAATCx  Patient1  AACCATGGTGTCAATC-1  CASH          1
# N3:AAAGTAGGTCTGATCAx  Patient1  AAAGTAGGTCTGATCA-1  CASH          1
# N3:AAACCTGTCATATCGGx  Patient1  AAACCTGTCATATCGG-1  CASH          1
#
#                                      cluster     UMAP1     UMAP2
# CellID
# N3:AACACGTTCATTGCCCx      c02_ Monocyte_CD14 -2.229901 -4.655958
# N3:AAACCTGTCACAAACCx      c02_ Monocyte_CD14 -2.963680 -4.877204
# N3:AACCATGGTGTCAATCx      c02_ Monocyte_CD14 -3.613648 -6.833498
# N3:AAAGTAGGTCTGATCAx        c05_ Macrophage_ -0.632350  1.862864
# N3:AAACCTGTCATATCGGx  c01_ Monocyte_CD14CD16 -0.766415 -2.732157
# AxisArrays with keys: umap
# NK_obj_meta.csv
# NK
#               barcode     orig.ident group   patient sub_celltype     UMAP1  \
# 0  AAACCTGCACCCATTC-1  CASH_Patient1  CASH  Patient1  c32_NK_CREM -6.797893
#
#       UMAP2
# 0  0.759612
# View of AnnData object with n_obs × n_vars = 2830 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id
# CellID
# N3:AAAGTAGCACCAACCGx  Patient1  AAAGTAGCACCAACCG-1  CASH          1
# N3:AAATGCCCAACTGGCCx  Patient1  AAATGCCCAACTGGCC-1  CASH          1
# N3:AAATGCCAGATGCCAGx  Patient1  AAATGCCAGATGCCAG-1  CASH          1
# N3:AACCGCGAGCGTGTCCx  Patient1  AACCGCGAGCGTGTCC-1  CASH          1
# N3:AACACGTCACAGGTTTx  Patient1  AACACGTCACAGGTTT-1  CASH          1
# ...                        ...                 ...   ...        ...
# N7:TTTGCGCTCTTGACGAx  Patient5  TTTGCGCTCTTGACGA-5  CASH          5
# N7:TTTGGTTAGACATAACx  Patient5  TTTGGTTAGACATAAC-5  CASH          5
# N7:TTTACTGAGATGTCGGx  Patient5  TTTACTGAGATGTCGG-5  CASH          5
# N7:TTTGGTTTCAAACAAGx  Patient5  TTTGGTTTCAAACAAG-5  CASH          5
# N7:TTTGGTTGTGCATCTAx  Patient5  TTTGGTTGTGCATCTA-5  CASH          5
#
# [2830 rows x 4 columns]
#                  barcode     orig.ident group   patient   sub_celltype  \
# 0     AAAGTAGCACCAACCG-1  CASH_Patient1  CASH  Patient1  c29_NK_NFKBIA
# 1     AAATGCCCAACTGGCC-1  CASH_Patient1  CASH  Patient1   c28_NK_CD160
# 2     AAATGCCAGATGCCAG-1  CASH_Patient1  CASH  Patient1  c29_NK_NFKBIA
# 3     AACCGCGAGCGTGTCC-1  CASH_Patient1  CASH  Patient1   c28_NK_CD160
# 4     AACACGTCACAGGTTT-1  CASH_Patient1  CASH  Patient1   c28_NK_CD160
# ...                  ...            ...   ...       ...            ...
# 2825  TTTGCGCTCTTGACGA-5  CASH_Patient5  CASH  Patient5   c28_NK_CD160
# 2826  TTTGGTTAGACATAAC-5  CASH_Patient5  CASH  Patient5    c33_NK_IL32
# 2827  TTTACTGAGATGTCGG-5  CASH_Patient5  CASH  Patient5    c32_NK_CREM
# 2828  TTTGGTTTCAAACAAG-5  CASH_Patient5  CASH  Patient5   c28_NK_CD160
# 2829  TTTGGTTGTGCATCTA-5  CASH_Patient5  CASH  Patient5   c28_NK_CD160
#
#          UMAP1     UMAP2
# 0     5.349980  1.551205
# 1     6.190370 -2.114345
# 2     6.889142  2.063839
# 3     6.882153 -3.509155
# 4     6.702590 -2.890710
# ...        ...       ...
# 2825  6.870509 -3.663442
# 2826 -5.441734 -0.494517
# 2827 -8.343521  1.081439
# 2828  5.210805 -2.146205
# 2829  6.745072 -3.058479
#
# [2830 rows x 7 columns]
# AnnData object with n_obs × n_vars = 2830 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id', 'cluster', 'UMAP1', 'UMAP2'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     obsm: 'umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id  \
# CellID
# N3:AAAGTAGCACCAACCGx  Patient1  AAAGTAGCACCAACCG-1  CASH          1
# N3:AAATGCCCAACTGGCCx  Patient1  AAATGCCCAACTGGCC-1  CASH          1
# N3:AAATGCCAGATGCCAGx  Patient1  AAATGCCAGATGCCAG-1  CASH          1
# N3:AACCGCGAGCGTGTCCx  Patient1  AACCGCGAGCGTGTCC-1  CASH          1
# N3:AACACGTCACAGGTTTx  Patient1  AACACGTCACAGGTTT-1  CASH          1
#
#                             cluster     UMAP1     UMAP2
# CellID
# N3:AAAGTAGCACCAACCGx  c29_NK_NFKBIA  5.349980  1.551205
# N3:AAATGCCCAACTGGCCx   c28_NK_CD160  6.190370 -2.114345
# N3:AAATGCCAGATGCCAGx  c29_NK_NFKBIA  6.889142  2.063839
# N3:AACCGCGAGCGTGTCCx   c28_NK_CD160  6.882153 -3.509155
# N3:AACACGTCACAGGTTTx   c28_NK_CD160  6.702590 -2.890710
# AxisArrays with keys: umap
# T_obj_meta.csv
# T
#               barcode     orig.ident group   patient sub_celltype     UMAP1  \
# 0  AAACCTGCAAATCCGT-1  CASH_Patient1  CASH  Patient1     c17_CD8_ -2.918159
#
#       UMAP2
# 0 -1.970783
# View of AnnData object with n_obs × n_vars = 8539 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id
# CellID
# N3:AACCATGCAGTCACTAx  Patient1  AACCATGCAGTCACTA-1  CASH          1
# N3:AACACGTTCCTCTAGCx  Patient1  AACACGTTCCTCTAGC-1  CASH          1
# N3:AAAGATGAGCTAAACAx  Patient1  AAAGATGAGCTAAACA-1  CASH          1
# N3:AAACGGGGTATCACCAx  Patient1  AAACGGGGTATCACCA-1  CASH          1
# N3:AAAGATGGTTACGTCAx  Patient1  AAAGATGGTTACGTCA-1  CASH          1
# ...                        ...                 ...   ...        ...
# N7:TTTGGTTGTGCTGTATx  Patient5  TTTGGTTGTGCTGTAT-5  CASH          5
# N7:TTTGTCAAGCTAACTCx  Patient5  TTTGTCAAGCTAACTC-5  CASH          5
# N7:TTTGGTTCAGGTCCACx  Patient5  TTTGGTTCAGGTCCAC-5  CASH          5
# N7:TTTGTCAAGAATGTGTx  Patient5  TTTGTCAAGAATGTGT-5  CASH          5
# N7:TTTGTCATCGAACGGAx  Patient5  TTTGTCATCGAACGGA-5  CASH          5
#
# [8539 rows x 4 columns]
#                  barcode     orig.ident group   patient  sub_celltype  \
# 0     AACCATGCAGTCACTA-1  CASH_Patient1  CASH  Patient1      c17_CD8_
# 1     AACACGTTCCTCTAGC-1  CASH_Patient1  CASH  Patient1      c17_CD8_
# 2     AAAGATGAGCTAAACA-1  CASH_Patient1  CASH  Patient1      c20_CD8_
# 3     AAACGGGGTATCACCA-1  CASH_Patient1  CASH  Patient1      c18_CD8_
# 4     AAAGATGGTTACGTCA-1  CASH_Patient1  CASH  Patient1      c21_CD8_
# ...                  ...            ...   ...       ...           ...
# 8534  TTTGGTTGTGCTGTAT-5  CASH_Patient5  CASH  Patient5      c17_CD8_
# 8535  TTTGTCAAGCTAACTC-5  CASH_Patient5  CASH  Patient5  c15_CD8_MAIT
# 8536  TTTGGTTCAGGTCCAC-5  CASH_Patient5  CASH  Patient5      c25_CD4_
# 8537  TTTGTCAAGAATGTGT-5  CASH_Patient5  CASH  Patient5  c15_CD8_MAIT
# 8538  TTTGTCATCGAACGGA-5  CASH_Patient5  CASH  Patient5  c14_CD8_MAIT
#
#          UMAP1     UMAP2
# 0    -4.316454 -2.035403
# 1    -4.613528 -3.733179
# 2    -4.659163 -0.412528
# 3    -4.289020 -3.974994
# 4    -6.139255  3.099605
# ...        ...       ...
# 8534 -2.049340 -0.969109
# 8535  4.474166  1.283799
# 8536  2.978903 -0.392170
# 8537  5.155301  1.809147
# 8538  4.704521  5.060831
#
# [8539 rows x 7 columns]
# AnnData object with n_obs × n_vars = 8539 × 37487
#     obs: 'patient', 'barcode', 'group', 'patient_id', 'cluster', 'UMAP1', 'UMAP2'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     obsm: 'umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#                        patient             barcode group patient_id   cluster  \
# CellID
# N3:AACCATGCAGTCACTAx  Patient1  AACCATGCAGTCACTA-1  CASH          1  c17_CD8_
# N3:AACACGTTCCTCTAGCx  Patient1  AACACGTTCCTCTAGC-1  CASH          1  c17_CD8_
# N3:AAAGATGAGCTAAACAx  Patient1  AAAGATGAGCTAAACA-1  CASH          1  c20_CD8_
# N3:AAACGGGGTATCACCAx  Patient1  AAACGGGGTATCACCA-1  CASH          1  c18_CD8_
# N3:AAAGATGGTTACGTCAx  Patient1  AAAGATGGTTACGTCA-1  CASH          1  c21_CD8_
#
#                          UMAP1     UMAP2
# CellID
# N3:AACCATGCAGTCACTAx -4.316454 -2.035403
# N3:AACACGTTCCTCTAGCx -4.613528 -3.733179
# N3:AAAGATGAGCTAAACAx -4.659163 -0.412528
# N3:AAACGGGGTATCACCAx -4.289020 -3.974994
# N3:AAAGATGGTTACGTCAx -6.139255  3.099605
# AxisArrays with keys: umap
